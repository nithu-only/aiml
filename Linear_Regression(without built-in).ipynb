# %%
import pandas as pd
import numpy as np
import math
import operator
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('DATSETS/Salary_Data.csv')
print(data.head())
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
X=data['YearsExperience'].values
Y=data['Salary'].values

# %%
plt.scatter(X,Y)

# %%
meanx=np.mean(X)
meany=np.mean(Y)
print(meanx,meany)
# Out:
# 5.3133333333333335 76003.0

# %%
# now let us find the slope and intercept
m=len(X)
numerator=0
denominator=0

for i in range(m):
    numerator += (X[i]-meanx)*(Y[i]-meany)
    denominator += (X[i]-meanx)**2

m=numerator/denominator

c=meany-(m*meanx)

print("The slope is --->",m)
print("The intercept is--->",c)
# Out:
# The slope is ---> 9449.962321455077
# The intercept is---> 25792.20019866869

# %%
# Plotting the scatter plot of data points
plt.scatter(X, Y, color='blue', label='Data Points')

# Plotting the regression line
regression_line = m*X + c
plt.plot(X, regression_line, color='red', label='Regression Line')

# Adding labels and title
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression')
plt.legend()

# Displaying the plot
plt.show()

# %%
# now let us calculate goodness of fit of our model
d=0
n=0

for i in range(5):
    ypred = c+m*X[i]
    n += (ypred-Y[i])
    d += (meany-Y[i])
result = 1-(n/d)

print(result)
# Out:
# 1.0068618982395017
